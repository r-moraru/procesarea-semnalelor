# %%
import math

# %%
def getFourierMatrix(N):
    return [
        [ math.e**(2j*math.pi*k*m/N) for k in range(N)]
        for m in range(N)
    ]

# %%
getFourierMatrix(8)
# Out:
# [[(1+0j), (1+0j), (1+0j), (1+0j), (1+0j), (1+0j), (1+0j), (1+0j)],
#  [(1+0j),
#   (0.992197667229329+0.12467473338522769j),
#   (0.9689124217106447+0.24740395925452294j),
#   (0.9305076219123143+0.36627252908604757j),
#   (0.8775825618903728+0.479425538604203j),
#   (0.8109631195052179+0.5850972729404622j),
#   (0.7316888688738209+0.6816387600233341j),
#   (0.6409968581633252+0.7675435022360271j)],
#  [(1+0j),
#   (0.9689124217106447+0.24740395925452294j),
#   (0.8775825618903728+0.479425538604203j),
#   (0.7316888688738209+0.6816387600233341j),
#   (0.5403023058681398+0.8414709848078965j),
#   (0.3153223623952687+0.9489846193555862j),
#   (0.0707372016677029+0.9974949866040544j),
#   (-0.17824605564949209+0.9839859468739369j)],
#  [(1+0j),
#   (0.9305076219123143+0.36627252908604757j),
#   (0.7316888688738209+0.6816387600233341j),
#   (0.4311765167986662+0.9022675940990952j),
#   (0.0707372016677029+0.9974949866040544j),
#   (-0.29953350618957414+0.9540857816096938j),
# ...

# %%
def sinusoidal(x):
    return 2*math.sin(2*math.pi*)
