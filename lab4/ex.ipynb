# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Ex 2
def semnal1(x):
    return np.sin(2*math.pi*220*x)

# %%
fs = 2**6*220
domain = np.arange(0, 2**-6, 1/fs)
plt.plot(domain, semnal1(domain))
